# %% [markdown]
# ![alt text](http://www.civictechs.com/wp-content/uploads/2019/06/instruct2.jpg)
#
# # Using APIs

# %% [markdown]
# # Application Programming Interfaces (APIs)
#
# Application Programming Interfaces -- or "APIs" -- allow you to talk with a remote server that does the computational work. An API is basically a program running on a server that you can send data to and receive data from. The way this works is your computer sends a GET URL request over the network to a server, much as when you load a web page. The server interprets the request, draws data from a database (if necessary), performs some action, and sends a response. The way you send and receive data is similar to what happens when you access a webpage:
# ![alt text](http://www.civictechs.com/wp-content/uploads/2019/06/HTTP-request-and-reply.png)
#
# For example, the API below sends a request to the CKAN (Comprehensive Knowledge Archive Network) server for LA Counts asking for a list of all the data sets on the site. The server sends back a JSON-formatted reply. [JSON](https://www.json.org/) is a lightweight data transmission format that is often used for sending data across the Internet.

# %%
# Import the requests and pretty print libraries. 
import requests 
# pprint lets us print out the JSON reply in an easily-readable format. 
import pprint
  
# Save the URL as a variable 
URL = "https://www.lacounts.org/api/3/action/package_list"
  
# Sending get request and saving the response as response object 
r = requests.get(url = URL) 
  
# Saving data in JSON format 
data = r.json() 
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(data)

# %% [markdown]
# # Why use APIs?
#
# There are several reasons why companies like APIs. Functionally, companies like APIs because they get more people to use their platform. Many offer paid services through a subscription model. So the more people try a platform out, the more they are likely to pay for a more powerful version! Many tasks are only possible on a server. You wouldn't want to give just anyone direct access to your data! APIs also give companies a layer of control. They can control how much processing power and network traffic you use.
#
# APIs also offer a balance between accessibility and security. To use an API, you will just need an API username and key. Your username and key are like your login and password to a website. In this way, companies can control who has access to an API. For example, if someone creates a program that uses an API in a way the company isn't comfortable with then can deactivate your that person's username and password. For example, if a mobile application accesses Facebook in a way that violates their terms of service, Facebook can shut that application down.

# %% [markdown]
# # Using APIs in Libraries
#
# Modern APIs often "wrap" the client-server connection described above in a library. That means you access an API just as with any library, using Python format data and methods! This may be a little confusing at first, because you have to sign up for APIs much like you would a social media account. Then you can access the APIs by importing a library. But there is a big advantage to accessing APIs through a library: you don't have to worry about the network part of an API that is happening behind the scenes, and you can focus on the data analysis.
#
# The signup process for an API is as simple as any website. You will need to give the website your email, username, and password. Then you will have access to the username and key to use the API in your Python library.
#
# In fact, you can sign up for the two APIs we will use in these Instructables right now!
#
# *   **To sign up for a Plot.ly API account, [follow this link](https://plot.ly/feed) and click on “sign up.”**
# *   **To sign up for a MapBox API account, [follow this link](https://account.mapbox.com/auth/signup/) and fill out at least the email, username, and password fields.**

# %% [markdown]
# # About the CKAN API
#
# The public (non-password protected) CKAN API enables you to retrieve a wealth of information about the data sets it hosts. The documentation for the CKAN API can be found [here](https://docs.ckan.org/en/2.8/api/index.html). For example, the code below performs a remote search to find datasets with specific keywords using the function package_search. You could build on this code to create a Python program that makes an automated request to detect when new budget data arrives on the site.

# %%
# Import the requests and pretty print libraries. 
import requests 
# pprint lets us print out the JSON reply in an easily-readable format. 
import pprint
  
# Save the URL as a variable - same as before, but a variable "q" (the search 
# query) is passed with the value "budget"
URL = "https://www.lacounts.org/api/3/action/package_search?q=budget"
  
# Sending get request and saving the response as response object 
r = requests.get(url = URL) 
  
# Saving data in JSON format 
data = r.json() 
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(data)
# Out:
# {   'help': 'https://www.lacounts.org/api/3/action/help_show?name=package_search',
#     'result': {   'count': 83,
#                   'facets': {},
#                   'results': [   {   'author': None,
#                                      'author_email': None,
#                                      'contact_name': 'Alicia Brown',
#                                      'creator_user_id': '19725249-9db6-4811-96a3-78867a9cb439',
#                                      'extras': [   {   'key': 'categories',
#                                                        'value': '{finance}'},
#                                                    {   'key': 'owner_display_name',
#                                                        'value': 'Alicia Brown'},
#                                                    {   'key': 'source_created_at',
#                                                        'value': '2015-02-17T21:06:50.000Z'},
#                                                    {   'key': 'source_updated_at',
#                                                        'value': '2019-06-14T14:05:17.000Z'},
#                                                    {   'key': 'harvest_object_id',
#                                                        'value': '36e98b4c-cf8c-41a0-8031-1986d169e756'}],
#                                      'groups': [],
#                                      'harvest_dataset_terms': [   'budget',
#                                                                   'capital-budget',
#                                                                   'capital',
#                                                                   'open-budget',
#                                                                   'finance',
#                                                                   'capital '
#                                                                   'budget'],
#                                      'harvest_dataset_url': 'https://data.culvercity.org/d/nwg8-v9b8',
#                                      'harvest_source_id': '77b8e86a-a8be-409b-b153-63f637d1de0a',
#                                      'harvest_source_title': 'City of Culver '
#                                                              'City Data Portal',
#                                      'harvest_source_url': 'https://data.culvercity.org',
#                                      'harvest_timestamp': '2019-06-18T20:00:36.287626',
#                                      'id': '76050031-a524-442f-9725-84ab5bce3c4a',
#                                      'identifier': 'nwg8-v9b8',
#                                      'isopen': False,
#                                      'issued': '2015-02-17T21:06:50+00:00',
#                                      'license_title': None,
#                                      'maintainer': None,
#                                      'maintainer_email': None,
#                                      'metadata_created': '2019-02-26T16:59:47.563464',
#                                      'metadata_modified': '2019-06-18T20:00:36.816539',
#                                      'modified': '2019-06-14T14:05:17+00:00',
#                                      'name': 'open-budget-capital-budget',
#                                      'notes': '',
#                                      'num_resources': 1,
#                                      'num_tags': 4,
#                                      'organization': {   'approval_status': 'approved',
#                                                          'created': '2018-10-08T13:50:12.839810',
#                                                          'description': '',
#                                                          'id': '93aee790-2c02-4463-aa54-891a6a45a72b',
#                                                          'image_url': '',
#                                                          'is_organization': True,
#                                                          'name': 'city-of-culver-city',
#                                                          'revision_id': '8253cacd-d34e-4827-bcf2-1b4e2942c5bd',
#                                                          'state': 'active',
#                                                          'title': 'Culver '
#                                                                   'City, City '
#                                                                   'of',
#                                                          'type': 'publisher'},
#                                      'owner_org': '93aee790-2c02-4463-aa54-891a6a45a72b',
#                                      'private': False,
#                                      'provenance': 'official',
#                                      'relationships_as_object': [],
#                                      'relationships_as_subject': [],
#                                      'resources': [   {   'cache_last_updated': None,
#                                                           'cache_url': None,
#                                                           'created': '2019-06-18T20:00:36.973626',
#                                                           'datastore_active': True,
#                                                           'description': '',
#                                                           'format': 'CSV',
#                                                           'hash': '',
#                                                           'id': '5570fb48-403d-49ab-8e1c-77e5ace003f1',
#                                                           'last_modified': None,
#                                                           'mimetype': None,
#                                                           'mimetype_inner': None,
#                                                           'package_id': '76050031-a524-442f-9725-84ab5bce3c4a',
#                                                           'position': 0,
#                                                           'resource_type': None,
#                                                           'revision_id': '632006b4-2601-4fd4-b830-16bb875e8bce',
#                                                           'size': None,
#                                                           'state': 'active',
#                                                           'url': 'https://data.culvercity.org/api/views/nwg8-v9b8/rows.csv?accessType=DOWNLOAD',
#                                                           'url_type': None}],
#                                      'revision_id': '632006b4-2601-4fd4-b830-16bb875e8bce',
#                                      'state': 'active',
#                                      'tags': [   {   'display_name': 'budget',
#                                                      'id': '3edaa177-8128-40de-8813-c3b4a1138b38',
#                                                      'name': 'budget',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'capital',
#                                                      'id': '3adac605-4b0f-4d54-9826-61da566ed097',
#                                                      'name': 'capital',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'capital-budget',
#                                                      'id': 'e94b78fb-368b-4c9e-8743-2eb820f7d52a',
#                                                      'name': 'capital-budget',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'open-budget',
#                                                      'id': '814fa5dd-2f5a-4681-9d8f-365dec9e3877',
#                                                      'name': 'open-budget',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None}],
#                                      'title': 'Open Budget - Capital Budget',
#                                      'type': 'dataset',
#                                      'url': 'https://data.culvercity.org/d/nwg8-v9b8',
#                                      'version': None},
#                                  {   'author': None,
#                                      'author_email': None,
#                                      'contact_name': 'Alicia Brown',
#                                      'creator_user_id': '19725249-9db6-4811-96a3-78867a9cb439',
#                                      'extras': [   {   'key': 'categories',
#                                                        'value': '{finance,environment}'},
#                                                    {   'key': 'owner_display_name',
#                                                        'value': 'Alicia Brown'},
#                                                    {   'key': 'source_created_at',
#                                                        'value': '2015-02-17T21:41:09.000Z'},
#                                                    {   'key': 'source_updated_at',
#                                                        'value': '2019-06-14T14:03:44.000Z'},
#                                                    {   'key': 'harvest_object_id',
#                                                        'value': '71c161de-4cba-4e49-a6c4-af0fd01b292f'}],
#                                      'groups': [],
#                                      'harvest_dataset_terms': [   'budget',
#                                                                   'finance',
#                                                                   'environment',
#                                                                   'operating'],
#                                      'harvest_dataset_url': 'https://data.culvercity.org/d/anmc-2gjz',
#                                      'harvest_source_id': '77b8e86a-a8be-409b-b153-63f637d1de0a',
#                                      'harvest_source_title': 'City of Culver '
#                                                              'City Data Portal',
#                                      'harvest_source_url': 'https://data.culvercity.org',
#                                      'harvest_timestamp': '2019-06-18T20:00:34.358845',
#                                      'id': '772c9916-46b5-46bc-a355-7a6a6e29d8e0',
#                                      'identifier': 'anmc-2gjz',
#                                      'isopen': False,
#                                      'issued': '2015-02-17T21:41:09+00:00',
#                                      'license_title': None,
#                                      'maintainer': None,
#                                      'maintainer_email': None,
#                                      'metadata_created': '2019-02-26T16:59:46.004019',
#                                      'metadata_modified': '2019-06-18T20:00:34.643840',
#                                      'modified': '2019-06-14T14:03:44+00:00',
#                                      'name': 'open-budget-operating-budget',
#                                      'notes': '',
#                                      'num_resources': 1,
#                                      'num_tags': 1,
#                                      'organization': {   'approval_status': 'approved',
#                                                          'created': '2018-10-08T13:50:12.839810',
#                                                          'description': '',
#                                                          'id': '93aee790-2c02-4463-aa54-891a6a45a72b',
#                                                          'image_url': '',
#                                                          'is_organization': True,
#                                                          'name': 'city-of-culver-city',
#                                                          'revision_id': '8253cacd-d34e-4827-bcf2-1b4e2942c5bd',
#                                                          'state': 'active',
#                                                          'title': 'Culver '
#                                                                   'City, City '
#                                                                   'of',
#                                                          'type': 'publisher'},
#                                      'owner_org': '93aee790-2c02-4463-aa54-891a6a45a72b',
#                                      'private': False,
#                                      'provenance': 'official',
#                                      'relationships_as_object': [],
#                                      'relationships_as_subject': [],
#                                      'resources': [   {   'cache_last_updated': None,
#                                                           'cache_url': None,
#                                                           'created': '2019-06-18T20:00:34.781501',
#                                                           'datastore_active': False,
#                                                           'description': '',
#                                                           'format': 'CSV',
#                                                           'hash': '',
#                                                           'id': '23ab2844-ada7-440b-bd5c-03dfb776e4fc',
#                                                           'last_modified': None,
#                                                           'mimetype': None,
#                                                           'mimetype_inner': None,
#                                                           'package_id': '772c9916-46b5-46bc-a355-7a6a6e29d8e0',
#                                                           'position': 0,
#                                                           'resource_type': None,
#                                                           'revision_id': 'e3639a00-f654-49b8-92bd-8b5a21966596',
#                                                           'size': None,
#                                                           'state': 'active',
#                                                           'url': 'https://data.culvercity.org/api/views/anmc-2gjz/rows.csv?accessType=DOWNLOAD',
#                                                           'url_type': None}],
#                                      'revision_id': 'e3639a00-f654-49b8-92bd-8b5a21966596',
#                                      'state': 'active',
#                                      'tags': [   {   'display_name': 'budget',
#                                                      'id': '3edaa177-8128-40de-8813-c3b4a1138b38',
#                                                      'name': 'budget',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None}],
#                                      'title': 'Open Budget - Operating Budget',
#                                      'type': 'dataset',
#                                      'url': 'https://data.culvercity.org/d/anmc-2gjz',
#                                      'version': None},
#                                  {   'author': 'Controller',
#                                      'author_email': None,
#                                      'contact_name': "Controller's Office",
#                                      'creator_user_id': '19725249-9db6-4811-96a3-78867a9cb439',
#                                      'extras': [   {   'key': 'Data-Owner_Data-Owner',
#                                                        'value': "Controller's "
#                                                                 'Office'},
#                                                    {   'key': 'Department_Department',
#                                                        'value': 'Controller'},
#                                                    {   'key': 'Department_Division',
#                                                        'value': 'FMS'},
#                                                    {   'key': 'Department_System',
#                                                        'value': 'FMS'},
#                                                    {   'key': 'Update-Information_Refresh-Rate',
#                                                        'value': 'Monthly'},
#                                                    {   'key': 'categories',
#                                                        'value': '{finance}'},
#                                                    {   'key': 'license',
#                                                        'value': 'Creative '
#                                                                 'Commons '
#                                                                 'Attribution '
#                                                                 '4.0 '
#                                                                 'International'},
#                                                    {   'key': 'owner_display_name',
#                                                        'value': "Controller's "
#                                                                 'Office'},
#                                                    {   'key': 'source_created_at',
#                                                        'value': '2013-10-20T07:39:29.000Z'},
#                                                    {   'key': 'source_updated_at',
#                                                        'value': '2019-05-08T13:31:28.000Z'}],
#                                      'groups': [],
#                                      'harvest_dataset_terms': [   'expenditure',
#                                                                   'account',
#                                                                   'expenditures',
#                                                                   'general-fund',
#                                                                   'budget',
#                                                                   'appropriation',
#                                                                   'finance',
#                                                                   'city'],
#                                      'harvest_dataset_url': 'https://controllerdata.lacity.org/d/uyzw-yi8n',
#                                      'harvest_source_url': 'https://controllerdata.lacity.org',
#                                      'harvest_timestamp': '2019-05-09T01:55:29.561864',
#                                      'id': 'a0b24ea2-7655-4ebd-8503-6a4510d58728',
#                                      'identifier': 'uyzw-yi8n',
#                                      'isopen': False,
#                                      'issued': '2013-10-20T07:39:29+00:00',
#                                      'license_title': None,
#                                      'maintainer': None,
#                                      'maintainer_email': None,
#                                      'metadata_created': '2019-02-27T10:38:59.970096',
#                                      'metadata_modified': '2019-05-09T01:55:29.810331',
#                                      'modified': '2019-05-08T13:31:28+00:00',
#                                      'name': 'city-budget-and-expenditures1',
#                                      'notes': 'City Budget, Adjustments and '
#                                               'Expenditures since Budget '
#                                               'Fiscal Year 2012. Financial '
#                                               'data is shown by Budget Fiscal '
#                                               'Year.',
#                                      'num_resources': 1,
#                                      'num_tags': 6,
#                                      'organization': {   'approval_status': 'approved',
#                                                          'created': '2018-08-24T11:13:50.941787',
#                                                          'description': '',
#                                                          'id': 'fef69868-1037-411c-bfb5-f6159c02e2d3',
#                                                          'image_url': '',
#                                                          'is_organization': True,
#                                                          'name': 'city-controller',
#                                                          'revision_id': 'd38a54e9-a994-48bf-b6ab-0fd3685b4f95',
#                                                          'state': 'active',
#                                                          'title': 'LA City '
#                                                                   'Controller',
#                                                          'type': 'publisher'},
#                                      'owner_org': 'fef69868-1037-411c-bfb5-f6159c02e2d3',
#                                      'private': False,
#                                      'provenance': 'official',
#                                      'relationships_as_object': [],
#                                      'relationships_as_subject': [],
#                                      'resources': [   {   'cache_last_updated': None,
#                                                           'cache_url': None,
#                                                           'created': '2019-05-09T01:55:29.918129',
#                                                           'datastore_active': True,
#                                                           'description': '',
#                                                           'format': 'CSV',
#                                                           'hash': '',
#                                                           'id': '231412bd-4c02-4a22-9e93-ac0724317ab8',
#                                                           'last_modified': None,
#                                                           'mimetype': None,
#                                                           'mimetype_inner': None,
#                                                           'package_id': 'a0b24ea2-7655-4ebd-8503-6a4510d58728',
#                                                           'position': 0,
#                                                           'resource_type': None,
#                                                           'revision_id': '93c77d51-70ff-44db-983f-cd2d0d580864',
#                                                           'size': None,
#                                                           'state': 'active',
#                                                           'url': 'https://controllerdata.lacity.org/api/views/uyzw-yi8n/rows.csv?accessType=DOWNLOAD',
#                                                           'url_type': None}],
#                                      'revision_id': '93c77d51-70ff-44db-983f-cd2d0d580864',
#                                      'state': 'active',
#                                      'tags': [   {   'display_name': 'account',
#                                                      'id': 'd29a8a7e-7cdb-4bdd-8005-2dfb55a6bd87',
#                                                      'name': 'account',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'appropriation',
#                                                      'id': '952606e6-062b-4b80-ab40-69ec9c35c60f',
#                                                      'name': 'appropriation',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'budget',
#                                                      'id': '3edaa177-8128-40de-8813-c3b4a1138b38',
#                                                      'name': 'budget',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'expenditure',
#                                                      'id': '57aaf6f4-4350-46b3-830b-db2c41000d30',
#                                                      'name': 'expenditure',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'expenditures',
#                                                      'id': 'e9c74f7a-6be1-41dc-85d3-c2e941717c5e',
#                                                      'name': 'expenditures',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'general-fund',
#                                                      'id': 'dece5f0c-94b0-4f9e-975c-00dd9d441ee2',
#                                                      'name': 'general-fund',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None}],
#                                      'title': 'City Budget and Expenditures',
#                                      'type': 'dataset',
#                                      'url': 'https://controllerdata.lacity.org/d/uyzw-yi8n',
#                                      'version': None},
#                                  {   'author': 'Finance Department',
#                                      'author_email': None,
#                                      'contact_name': 'sreekanth',
#                                      'creator_user_id': '19725249-9db6-4811-96a3-78867a9cb439',
#                                      'extras': [   {   'key': 'Data-Freshness_Time-Period',
#                                                        'value': 'Expenditures '
#                                                                 '2010-2014 , '
#                                                                 'Budget '
#                                                                 '2013-17'},
#                                                    {   'key': 'Data-Freshness_Update-Frequency',
#                                                        'value': 'Yearly'},
#                                                    {   'key': 'categories',
#                                                        'value': '{finance,infrastructure,economy}'},
#                                                    {   'key': 'license',
#                                                        'value': 'Public '
#                                                                 'Domain'},
#                                                    {   'key': 'owner_display_name',
#                                                        'value': 'sreekanth'},
#                                                    {   'key': 'source_created_at',
#                                                        'value': '2014-09-09T15:58:43.000Z'},
#                                                    {   'key': 'source_updated_at',
#                                                        'value': '2015-10-09T21:33:51.000Z'}],
#                                      'groups': [   {   'description': '',
#                                                        'display_name': 'Community '
#                                                                        '+ '
#                                                                        'Economic '
#                                                                        'Development',
#                                                        'id': '31b006d4-5537-4b30-a5a4-a2d7b41ea2ec',
#                                                        'image_display_url': '',
#                                                        'name': 'community-economic-development',
#                                                        'title': 'Community + '
#                                                                 'Economic '
#                                                                 'Development'},
#                                                    {   'description': 'A quick '
#                                                                       'exploration '
#                                                                       'of '
#                                                                       'government '
#                                                                       'spending '
#                                                                       'data '
#                                                                       'can '
#                                                                       'reveal '
#                                                                       'a lot. '
#                                                                       'We all '
#                                                                       'pay '
#                                                                       'taxes, '
#                                                                       'where '
#                                                                       'does '
#                                                                       'the '
#                                                                       'money '
#                                                                       'go? '
#                                                                       'What do '
#                                                                       'the '
#                                                                       'different '
#                                                                       'cities '
#                                                                       'across '
#                                                                       'the '
#                                                                       'county '
#                                                                       'spend '
#                                                                       'their '
#                                                                       'money '
#                                                                       'on? If '
#                                                                       "that's "
#                                                                       'your '
#                                                                       'thing, '
#                                                                       'binge '
#                                                                       'on this '
#                                                                       'data. '
#                                                                       'Tell us '
#                                                                       'what '
#                                                                       'you '
#                                                                       'find! ',
#                                                        'display_name': 'Government '
#                                                                        'Spending',
#                                                        'id': '4117b4d7-86f9-43c2-b340-f66b2830bd28',
#                                                        'image_display_url': '',
#                                                        'name': 'government-spending',
#                                                        'title': 'Government '
#                                                                 'Spending'},
#                                                    {   'description': 'That '
#                                                                       'freeway '
#                                                                       'you '
#                                                                       'drove '
#                                                                       'on '
#                                                                       'yesterday? '
#                                                                       "That's "
#                                                                       'infrastructure. '
#                                                                       'The '
#                                                                       'water '
#                                                                       'main '
#                                                                       'that '
#                                                                       'broke '
#                                                                       'and '
#                                                                       'caused '
#                                                                       'a '
#                                                                       'traffic '
#                                                                       'jam, '
#                                                                       "that's "
#                                                                       'infrastructure, '
#                                                                       'too. '
#                                                                       "So's "
#                                                                       'the '
#                                                                       'electricity '
#                                                                       'that '
#                                                                       'your '
#                                                                       'barista '
#                                                                       'uses at '
#                                                                       'your '
#                                                                       'coffee '
#                                                                       'place. '
#                                                                       'The '
#                                                                       'built '
#                                                                       'environment '
#                                                                       'affects '
#                                                                       'us all. '
#                                                                       'What '
#                                                                       'are our '
#                                                                       'long '
#                                                                       'term '
#                                                                       'infrastructure '
#                                                                       'needs, '
#                                                                       'and '
#                                                                       'what '
#                                                                       'data do '
#                                                                       'we have '
#                                                                       'to '
#                                                                       'support '
#                                                                       'them? '
#                                                                       'Find '
#                                                                       'them '
#                                                                       'here. ',
#                                                        'display_name': 'Infrastructure',
#                                                        'id': '25e7bb94-21ed-4366-91e4-3123212237f7',
#                                                        'image_display_url': '',
#                                                        'name': 'infrastructure',
#                                                        'title': 'Infrastructure'}],
#                                      'harvest_dataset_terms': [   'capital',
#                                                                   'budget',
#                                                                   'projects',
#                                                                   'improvement-projects',
#                                                                   'expenditures',
#                                                                   'expenses',
#                                                                   'cip',
#                                                                   'finance',
#                                                                   'infrastructure',
#                                                                   'economy',
#                                                                   'expenditure',
#                                                                   'cip budget'],
#                                      'harvest_dataset_url': 'https://data.smgov.net/d/uywi-9ehj',
#                                      'harvest_source_url': 'http://data.smgov.net',
#                                      'harvest_timestamp': '2019-02-26T22:48:18.191614',
#                                      'id': 'd05c6cfe-37b7-4bdd-afc5-75b8f6f50cac',
#                                      'identifier': 'uywi-9ehj',
#                                      'isopen': False,
#                                      'issued': '2014-09-09T15:58:43+00:00',
#                                      'license_title': None,
#                                      'maintainer': None,
#                                      'maintainer_email': None,
#                                      'metadata_created': '2019-02-26T22:48:18.346742',
#                                      'metadata_modified': '2019-03-06T20:29:13.734470',
#                                      'modified': '2015-10-09T21:33:51+00:00',
#                                      'name': 'cip-budget-and-expenditure',
#                                      'notes': 'This includes Actuals and '
#                                               'Budget for Capital Improvement '
#                                               'Program (CIP) Projects.',
#                                      'num_resources': 1,
#                                      'num_tags': 7,
#                                      'organization': {   'approval_status': 'approved',
#                                                          'created': '2018-09-10T11:03:16.717678',
#                                                          'description': 'Some '
#                                                                         'publisher '
#                                                                         'description',
#                                                          'id': 'c1157041-a96e-4761-abd2-15be237c8a41',
#                                                          'image_url': '',
#                                                          'is_organization': True,
#                                                          'name': 'city-of-santa-monica',
#                                                          'revision_id': '90da62bc-5adf-4ee5-908f-2c4a0c23c64e',
#                                                          'state': 'active',
#                                                          'title': 'Santa '
#                                                                   'Monica, '
#                                                                   'City of ',
#                                                          'type': 'publisher'},
#                                      'owner_org': 'c1157041-a96e-4761-abd2-15be237c8a41',
#                                      'private': False,
#                                      'provenance': 'official',
#                                      'relationships_as_object': [],
#                                      'relationships_as_subject': [],
#                                      'resources': [   {   'cache_last_updated': None,
#                                                           'cache_url': None,
#                                                           'created': '2019-02-26T22:48:18.387973',
#                                                           'datastore_active': True,
#                                                           'description': '',
#                                                           'format': 'CSV',
#                                                           'hash': '',
#                                                           'id': 'd33e9d15-10ae-4df9-9e4b-c5afc55ccdbe',
#                                                           'last_modified': None,
#                                                           'mimetype': None,
#                                                           'mimetype_inner': None,
#                                                           'package_id': 'd05c6cfe-37b7-4bdd-afc5-75b8f6f50cac',
#                                                           'position': 0,
#                                                           'resource_type': None,
#                                                           'revision_id': '16e1ae97-bd12-42f4-a7ac-0b394ae7e536',
#                                                           'size': None,
#                                                           'state': 'active',
#                                                           'url': 'https://data.smgov.net/api/views/uywi-9ehj/rows.csv?accessType=DOWNLOAD',
#                                                           'url_type': None}],
#                                      'revision_id': '16e1ae97-bd12-42f4-a7ac-0b394ae7e536',
#                                      'state': 'active',
#                                      'tags': [   {   'display_name': 'budget',
#                                                      'id': '3edaa177-8128-40de-8813-c3b4a1138b38',
#                                                      'name': 'budget',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'capital',
#                                                      'id': '3adac605-4b0f-4d54-9826-61da566ed097',
#                                                      'name': 'capital',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'cip',
#                                                      'id': 'ef589176-6008-483c-a3e5-e8c8eaa1016b',
#                                                      'name': 'cip',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'expenditures',
#                                                      'id': 'e9c74f7a-6be1-41dc-85d3-c2e941717c5e',
#                                                      'name': 'expenditures',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'expenses',
#                                                      'id': 'c03e622c-32a6-4416-974c-f7d67aeed37f',
#                                                      'name': 'expenses',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'improvement-projects',
#                                                      'id': 'eb6992e8-da86-460d-9c3a-0dfb1cbfef77',
#                                                      'name': 'improvement-projects',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'projects',
#                                                      'id': 'ef09c361-377a-4f6b-bd04-c4ad2943720b',
#                                                      'name': 'projects',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None}],
#                                      'title': 'CIP Budget and Expenditure',
#                                      'type': 'dataset',
#                                      'url': 'https://data.smgov.net/d/uywi-9ehj',
#                                      'version': None},
#                                  {   'author': 'Finance Department',
#                                      'author_email': None,
#                                      'contact_name': 'sreekanth',
#                                      'creator_user_id': '19725249-9db6-4811-96a3-78867a9cb439',
#                                      'extras': [   {   'key': 'Data-Freshness_Time-Period',
#                                                        'value': 'Fiscal Year '
#                                                                 '2013-2017'},
#                                                    {   'key': 'Data-Freshness_Update-Frequency',
#                                                        'value': 'Yearly'},
#                                                    {   'key': 'categories',
#                                                        'value': '{finance,economy,infrastructure}'},
#                                                    {   'key': 'license',
#                                                        'value': 'Public '
#                                                                 'Domain'},
#                                                    {   'key': 'owner_display_name',
#                                                        'value': 'sreekanth'},
#                                                    {   'key': 'source_created_at',
#                                                        'value': '2014-09-09T15:51:10.000Z'},
#                                                    {   'key': 'source_updated_at',
#                                                        'value': '2015-10-21T23:19:28.000Z'}],
#                                      'groups': [   {   'description': '',
#                                                        'display_name': 'Community '
#                                                                        '+ '
#                                                                        'Economic '
#                                                                        'Development',
#                                                        'id': '31b006d4-5537-4b30-a5a4-a2d7b41ea2ec',
#                                                        'image_display_url': '',
# ...
#                                               'http://openbudget.lacity.org/\n'
#                                               '\n'
#                                               'Fiscal years 2010 - 2013 have '
#                                               'aggregate budgets per '
#                                               'department. 2014 - present '
#                                               'display line item '
#                                               'appropriations.',
#                                      'num_resources': 1,
#                                      'num_tags': 3,
#                                      'organization': {   'approval_status': 'approved',
#                                                          'created': '2018-08-23T10:33:04.837572',
#                                                          'description': '',
#                                                          'id': '44eda78f-d672-449c-8606-d27b15a2983e',
#                                                          'image_url': '',
#                                                          'is_organization': True,
#                                                          'name': 'city-of-los-angeles',
#                                                          'revision_id': 'cede4128-1b29-4495-8356-e64442afadf6',
#                                                          'state': 'active',
#                                                          'title': 'Los '
#                                                                   'Angeles, '
#                                                                   'City of',
#                                                          'type': 'publisher'},
#                                      'owner_org': '44eda78f-d672-449c-8606-d27b15a2983e',
#                                      'private': False,
#                                      'provenance': 'official',
#                                      'relationships_as_object': [],
#                                      'relationships_as_subject': [],
#                                      'resources': [   {   'cache_last_updated': None,
#                                                           'cache_url': None,
#                                                           'created': '2019-02-27T10:31:57.481331',
#                                                           'datastore_active': True,
#                                                           'description': '',
#                                                           'format': 'CSV',
#                                                           'hash': '',
#                                                           'id': '5b2e9aa8-b9e9-4aa3-8260-92c6923fbc5f',
#                                                           'last_modified': None,
#                                                           'mimetype': None,
#                                                           'mimetype_inner': None,
#                                                           'package_id': 'a54012ce-fb91-4488-a15b-82fd1147f756',
#                                                           'position': 0,
#                                                           'resource_type': None,
#                                                           'revision_id': '649e3b12-35ab-4282-87fa-6d52320d379f',
#                                                           'size': None,
#                                                           'state': 'active',
#                                                           'url': 'https://data.lacity.org/api/views/5242-pnmt/rows.csv?accessType=DOWNLOAD',
#                                                           'url_type': None}],
#                                      'revision_id': '649e3b12-35ab-4282-87fa-6d52320d379f',
#                                      'state': 'active',
#                                      'tags': [   {   'display_name': 'appropriations',
#                                                      'id': '1a0c9ab2-757e-4896-baa0-1fa94c4fd9b5',
#                                                      'name': 'appropriations',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'budget',
#                                                      'id': '3edaa177-8128-40de-8813-c3b4a1138b38',
#                                                      'name': 'budget',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'fiscal-year',
#                                                      'id': '68ea8358-0d10-4f7b-a155-12c7c10da156',
#                                                      'name': 'fiscal-year',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None}],
#                                      'title': 'Open Budget - Appropriations '
#                                               'Fiscal Years 2010 - 2019',
#                                      'type': 'dataset',
#                                      'url': 'https://data.lacity.org/d/5242-pnmt',
#                                      'version': None},
#                                  {   'author': None,
#                                      'author_email': None,
#                                      'contact_name': 'Jessica Carsten',
#                                      'creator_user_id': '19725249-9db6-4811-96a3-78867a9cb439',
#                                      'extras': [   {   'key': 'Committed-Update-Frequency_Refresh-rate',
#                                                        'value': 'Other - See '
#                                                                 'Description'},
#                                                    {   'key': 'Data-Owner_Department',
#                                                        'value': 'Other'},
#                                                    {   'key': 'Location-Specified_Does-this-data-have-a-Location-column?-(Yes-or-No)',
#                                                        'value': 'No'},
#                                                    {   'key': 'categories',
#                                                        'value': '{finance}'},
#                                                    {   'key': 'license',
#                                                        'value': 'Creative '
#                                                                 'Commons 1.0 '
#                                                                 'Universal '
#                                                                 '(Public '
#                                                                 'Domain '
#                                                                 'Dedication)'},
#                                                    {   'key': 'owner_display_name',
#                                                        'value': 'Jessica '
#                                                                 'Carsten'},
#                                                    {   'key': 'source_created_at',
#                                                        'value': '2014-04-22T16:30:05.000Z'},
#                                                    {   'key': 'source_updated_at',
#                                                        'value': '2018-10-26T23:51:34.000Z'}],
#                                      'groups': [   {   'description': '',
#                                                        'display_name': 'Community '
#                                                                        '+ '
#                                                                        'Economic '
#                                                                        'Development',
#                                                        'id': '31b006d4-5537-4b30-a5a4-a2d7b41ea2ec',
#                                                        'image_display_url': '',
#                                                        'name': 'community-economic-development',
#                                                        'title': 'Community + '
#                                                                 'Economic '
#                                                                 'Development'}],
#                                      'harvest_dataset_terms': [   'port',
#                                                                   'adopted',
#                                                                   'pola',
#                                                                   'budget',
#                                                                   'finance',
#                                                                   'los',
#                                                                   'angeles',
#                                                                   'los angeles',
#                                                                   'adopted '
#                                                                   'budget'],
#                                      'harvest_dataset_url': 'https://data.lacity.org/d/du8q-hww5',
#                                      'harvest_source_url': 'https://data.lacity.org',
#                                      'harvest_timestamp': '2019-02-27T10:35:48.479577',
#                                      'id': '52f4979b-abf5-482d-bb59-c9d89e782917',
#                                      'identifier': 'du8q-hww5',
#                                      'isopen': False,
#                                      'issued': '2014-04-22T16:30:05+00:00',
#                                      'license_title': None,
#                                      'maintainer': None,
#                                      'maintainer_email': None,
#                                      'metadata_created': '2019-02-27T10:35:48.744791',
#                                      'metadata_modified': '2019-03-06T20:26:06.080887',
#                                      'modified': '2018-10-26T23:51:34+00:00',
#                                      'name': 'port-of-los-angeles-adopted-budget-2010-2014',
#                                      'notes': 'POLA adopted budget for the '
#                                               'years 2010-2014.',
#                                      'num_resources': 1,
#                                      'num_tags': 4,
#                                      'organization': {   'approval_status': 'approved',
#                                                          'created': '2018-08-23T10:33:04.837572',
#                                                          'description': '',
#                                                          'id': '44eda78f-d672-449c-8606-d27b15a2983e',
#                                                          'image_url': '',
#                                                          'is_organization': True,
#                                                          'name': 'city-of-los-angeles',
#                                                          'revision_id': 'cede4128-1b29-4495-8356-e64442afadf6',
#                                                          'state': 'active',
#                                                          'title': 'Los '
#                                                                   'Angeles, '
#                                                                   'City of',
#                                                          'type': 'publisher'},
#                                      'owner_org': '44eda78f-d672-449c-8606-d27b15a2983e',
#                                      'private': False,
#                                      'provenance': 'official',
#                                      'relationships_as_object': [],
#                                      'relationships_as_subject': [],
#                                      'resources': [   {   'cache_last_updated': None,
#                                                           'cache_url': None,
#                                                           'created': '2019-02-27T10:35:48.789901',
#                                                           'datastore_active': True,
#                                                           'description': '',
#                                                           'format': 'CSV',
#                                                           'hash': '',
#                                                           'id': '2156c9af-f6ac-47fd-a13f-36096124d525',
#                                                           'last_modified': None,
#                                                           'mimetype': None,
#                                                           'mimetype_inner': None,
#                                                           'package_id': '52f4979b-abf5-482d-bb59-c9d89e782917',
#                                                           'position': 0,
#                                                           'resource_type': None,
#                                                           'revision_id': '5bd462ca-aca2-4427-b529-e970ef2b4a47',
#                                                           'size': None,
#                                                           'state': 'active',
#                                                           'url': 'https://data.lacity.org/api/views/du8q-hww5/rows.csv?accessType=DOWNLOAD',
#                                                           'url_type': None}],
#                                      'revision_id': '5bd462ca-aca2-4427-b529-e970ef2b4a47',
#                                      'state': 'active',
#                                      'tags': [   {   'display_name': 'adopted',
#                                                      'id': 'a58c6f26-c454-42bd-a6e8-9098a4d59bff',
#                                                      'name': 'adopted',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'budget',
#                                                      'id': '3edaa177-8128-40de-8813-c3b4a1138b38',
#                                                      'name': 'budget',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'pola',
#                                                      'id': '13b9ac91-025b-4bb2-8be7-859a03a4c86f',
#                                                      'name': 'pola',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None},
#                                                  {   'display_name': 'port',
#                                                      'id': '28b7abfa-a97f-4c42-8bd2-7c2808099a5d',
#                                                      'name': 'port',
#                                                      'state': 'active',
#                                                      'vocabulary_id': None}],
#                                      'title': 'Port Of Los Angeles - Adopted '
#                                               'Budget 2010 - 2014',
#                                      'type': 'dataset',
#                                      'url': 'https://data.lacity.org/d/du8q-hww5',
#                                      'version': None}],
#                   'search_facets': {},
#                   'sort': 'score desc, metadata_modified desc'},
#     'success': True}
